# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Variables

# %%
T_e=1
T=1000
sigma_Q=1
sigma_px=30
sigma_py=30

# %%
F=np.array([[1,T_e,0,0],[0,1,0,0],[0,0,1,T_e],[0,0,0,1]])
Q=sigma_Q*np.array([[T_e**3/3,T_e**2/2,0,0],[T_e**2/2,T_e,0,0],[0,0,T_e**3/3,T_e**2/2],[0,0,T_e**2,T_e]])
H=np.array([[1,0,0,0],[0,0,1,0]])
R=np.array([[sigma_px**2,0],[0,sigma_py**2]])

# %%
x_init=np.array([[3],[40],[-4],[20]])
x_kalm=x_init
P_kalm=np.identity(4)

# %% [markdown]
# # Fonctions

# %%
def creer_trajectoire(F=F,Q=Q,x_init=x_init,T=T):
    x=x_init
    vecteur_x=np.zeros((4,T))
    vecteur_x[:,0]=x_init.reshape((4,))
    for n in range(1,T):
        U=np.random.multivariate_normal([0,0,0,0],Q).reshape((4,1))
        x=F@x+U
        vecteur_x[:,n]=x.reshape((4,))
    return vecteur_x
vecteur_x=creer_trajectoire()
# Out:
# /tmp/ipykernel_2736591/1551965814.py:6: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   U=np.random.multivariate_normal([0,0,0,0],Q).reshape((4,1))

# %%
def creer_observation(vecteur_x,H=H,R=R,T=T):
    vecteur_y=np.zeros((2,T))
    for n in range(T):
        x=vecteur_x[:,n]
        V=np.random.multivariate_normal([0,0],R).reshape((2,1))
        y=H@x+V.T
        vecteur_y[:,n]=y.reshape((2,))
    return vecteur_y

# %%
def filtre_de_kalman(y_k,x_kalm_prec,P_kalm_prec,F=F,Q=Q,H=H,R=R):
    y_k=y_k.reshape((2,1))
    x_kalm=F@x_kalm_prec
    #print(x_kalm.shape)
    P_kalm=F@P_kalm_prec@F.T + Q
    #print(P_kalm.shape)
    temp=H@P_kalm@H.T+R
    temp=np.linalg.inv(temp)
    K=P_kalm@H.T@temp
    #print(K.shape)
    P_kalm_k=(np.identity(4) - K@H)@P_kalm
    #print(P_kalm_k.shape)
    x_kalm_k=x_kalm+K@(y_k-H@x_kalm)
    #print(x_kalm_k)
    return x_kalm_k,P_kalm_k

# %%
def filtre_de_kalman_v2(y_k1,x_kalm_k_k,P_kalm_k_k,F=F,Q=Q,H=H,R=R):
    x_kalm_k1_k = F @ x_kalm_k_k # Calcule m k=1 sachant k
    P_kalm_k1_k = (F @ P_kalm_k_k @ F.T) + Q
    
    # Si il n'y a pas d'observation on renvois l'estimateur k+1 sachant k
    if False: # y_k1 == ["NaN", "NaN"]:
        return x_kalm_k1_k
    # Sinon on continue !
    y_k1 = y_k1.reshape((2,1)) # Nouelle abservation
    
    K = P_kalm_k1_k @ H.T @ np.linalg.inv((H @ P_kalm_k1_k @ H.T) + R)
    
    # print(x_kalm_k1_k.shape)
    # print((H @ x_kalm_k1_k).shape, np.identity(4).shape, K.shape)
    
    x_kalm_k1_k1 = x_kalm_k1_k + K @ (y_k1 - (H @ x_kalm_k1_k))
    P_kalm_k1_k1 = (np.identity(4) - K@H) @ P_kalm_k1_k
    

    return x_kalm_k1_k1, P_kalm_k1_k1

# %%
def kalman_recursif(vecteur_y,vecteur_y0,x_kalm=x_kalm,P_kalm=P_kalm,T=T):
    x_est=np.zeros((4,T))
    x_est[:,0]=x_kalm.reshape((4,))
    for n in range(1,T):
        x_kalm,P_kalm=filtre_de_kalman(vecteur_y[:,n],x_kalm,P_kalm)
        x_est[:,n]=x_kalm.reshape((4,))
    return x_est

# %% [markdown]
# # Main

# %%
vecteur_x=creer_trajectoire()
vecteur_y=creer_observation(vecteur_x)
x_est=kalman_recursif(vecteur_y,x_init)
# Out:
# /tmp/ipykernel_2736591/1551965814.py:6: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   U=np.random.multivariate_normal([0,0,0,0],Q).reshape((4,1))

# %%
err_quadra = np.zeros(T)
for t in range(T):
    err_quadra[t] = ((vecteur_x[:, t] - x_est[:, t]).T)@(vecteur_x[:, t] - x_est[:, t])

erreur_moyenne = (1/T) * np.sum(np.sqrt(err_quadra))
print('erreur moyenne = ', erreur_moyenne)
# Out:
# erreur moyenne =  19.18854192459263

# %%
dfx=pd.DataFrame(vecteur_x.T,columns=['px','px.','py','py.'])
dfy=pd.DataFrame(vecteur_y.T,columns=['Opx','Opy'])
dfest=pd.DataFrame(x_est.T,columns=['Estpx','Estpx.','Estpy','Estpy.'])
df=pd.concat([dfx,dfy,dfest],axis=1)

# %%
df
# Out:
#                px        px.            py        py.           Opx  \
# 0        3.000000  40.000000     -4.000000  20.000000    -33.155910
# 1       42.506712  38.707108     15.291585  19.528343     30.428331
# 2       81.786789  40.043467     35.166235  19.830848    130.243136
# 3      121.473677  39.653174     54.851776  19.195219    118.019771
# 4      161.372866  39.444711     74.536680  19.817680    164.708302
# ..            ...        ...           ...        ...           ...
# 995  33356.779525  30.412240  18478.106880  21.922676  33355.099506
# 996  33387.903619  31.308008  18499.132504  21.358912  33419.013868
# 997  33417.848601  28.714458  18520.136377  21.461492  33393.193080
# 998  33446.566161  28.776494  18540.511916  20.257203  33465.450214
# 999  33475.189361  28.974678  18559.086725  18.539598  33494.939652
#
#               Opy         Estpx     Estpx.         Estpy     Estpy.
# 0       17.610894      3.000000  40.000000     -4.000000  20.000000
# 1       43.973898     42.967491  39.979101     16.072337  20.062003
# 2       28.042832     83.345244  40.187204     36.061741  20.017530
# 3       95.685746    123.419539  40.142567     56.952360  20.401483
# 4       74.974031    163.607674  40.156884     77.252408  20.366985
# ..            ...           ...        ...           ...        ...
# 995  18479.769268  33351.352122  29.593375  18474.889190  21.018277
# 996  18530.905560  33389.608272  30.708634  18503.858882  22.077431
# 997  18557.539801  33414.144654  29.914009  18533.116489  23.033853
# 998  18512.335905  33448.926488  30.540700  18546.195892  21.707889
# 999  18541.774273  33482.988076  30.993985  18561.967269  20.917127
#
# [1000 rows x 10 columns]

# %%
plt.

    # Assuming df is your DataFrame
    plt.plot(df['px'], df['py'], label='reel')
    plt.plot(df['Opx'], df['Opy'], label='observation')
    plt.plot(df['Estpx'], df['Estpy'], label='estimation')
    
    # Set labels and title
    plt.xlabel('X-axis label')
    plt.ylabel('Y-axis label')
    plt.title('reel vs observation vs estimation')

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
df[90:100]
# Out:
#              px        px.           py        py.          Opx          Opy  \
# 90  3954.211095  48.707681  1819.565986  23.595215  3987.862183  1786.667361
# 91  4002.772515  48.181495  1843.901479  24.265510  4027.282034  1906.953047
# 92  4050.166097  46.075565  1866.417757  24.351435  4021.411324  1872.156914
# 93  4095.953429  45.896978  1890.370379  24.105979  4118.770093  1852.882909
# 94  4141.666262  46.010870  1914.416853  24.404803  4211.492231  1932.020675
# 95  4188.179853  46.435273  1938.456968  23.848391  4256.819274  1994.297065
# 96  4233.959344  44.532514  1962.002009  23.724788  4223.608177  1985.837975
# 97  4278.411985  44.489281  1985.301318  23.719501  4287.497989  1973.432588
# 98  4323.141304  44.464151  2009.268827  23.966270  4295.617642  2020.812041
# 99  4367.889969  44.717318  2033.236342  23.719215  4326.749894  1996.038219
#
#           Estpx     Estpx.        Estpy     Estpy.
# 90  3948.229640  46.868580  1785.733262  19.194036
# 91  4002.421915  47.811444  1828.107107  22.281660
# 92  4043.674665  46.967067  1855.334396  22.940433
# 93  4097.042575  47.791122  1872.505895  22.171993
# 94  4160.002402  49.743965  1903.162008  23.302105
# 95  4220.458200  51.123023  1941.875466  25.354946
# 96  4260.664557  49.717594  1971.457970  25.918070
# 97  4305.174669  49.047175  1991.936191  25.193465
# 98  4340.885970  47.330293  2017.966278  25.304906
# 99  4374.229078  45.529561  2032.540058  23.875486
